# %%
import numpy as np

csv_path = "iris.csv"

# %%
def load_csv(path: str):
    return np.genfromtxt(path, delimiter=',')


load_csv(csv_path)
# Out:
# array([[ 5.100e+00,  3.500e+00,  1.400e+00,  2.000e-01,  0.000e+00],
#        [ 4.900e+00,  3.000e+00,  1.400e+00,  2.000e-01,  0.000e+00],
#        [ 4.700e+00,  3.200e+00,  1.300e+00,  2.000e-01,  0.000e+00],
#        [ 4.600e+00,  3.100e+00,  1.500e+00,  2.000e-01,  0.000e+00],
#        [ 5.000e+00,  3.600e+00,  1.400e+00,  2.000e-01,  0.000e+00],
#        [ 5.400e+00,  3.900e+00,  1.700e+00,        nan,  0.000e+00],
#        [ 4.600e+00,  3.400e+00,  1.400e+00,  3.000e-01,  0.000e+00],
#        [ 5.000e+00,  3.400e+00,  1.500e+00,  2.000e-01,  0.000e+00],
#        [ 4.400e+00,  2.900e+00,  1.400e+00,  2.000e-01,  0.000e+00],
#        [ 4.900e+00,  3.100e+00,  1.500e+00,  1.000e-01,  0.000e+00],
#        [ 5.400e+00,  3.700e+00,  1.500e+00,  2.000e-01,  0.000e+00],
#        [       nan,  3.400e+00,  1.600e+00,  2.000e-01,  0.000e+00],
#        [ 4.800e+00,  3.000e+00,  1.400e+00,  1.000e-01,  0.000e+00],
#        [ 4.300e+00,  3.000e+00,  1.100e+00,  1.000e-01,  0.000e+00],
# ...
